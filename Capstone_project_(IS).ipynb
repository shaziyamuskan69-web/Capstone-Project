# %% [markdown]
# <a href="https://colab.research.google.com/github/shaziyamuskan69-web/Capstone-Project/blob/main/Capstone_project_(IS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *INFERENTIAL STATISTICS*

# %%
import pandas as pd
from google.colab import files

# Upload file
uploaded = files.upload()

# Load the CSV (replace with your filename)
df = pd.read_csv(list(uploaded.keys())[0])

df
# Out:
#      <input type="file" id="files-ae1d4702-7dc6-43b7-8456-c580cd0f1332" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae1d4702-7dc6-43b7-8456-c580cd0f1332">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Task
# Analyze the provided DataFrame `df` loaded from `test_lAUu6dG (1).csv` by performing the following steps: prepare the data by handling missing values and converting data types for 'Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', and 'Gender'; conduct a Chi-square test between 'Loan_Status' and 'Married'; visualize the distribution of 'Loan_Status' with a countplot; create a bar chart of average total income (ApplicantIncome + CoapplicantIncome) vs. 'Loan_Status'; generate a correlation heatmap for relevant numerical columns; create a boxplot of 'LoanAmount' by 'Education' level; and display a pie chart of loan approvals by 'Gender'. Finally, summarize all findings from these inferential statistics and visualizations, focusing on insights into loan approval influenced by income, marital status, education, and gender.

# %% [markdown]
# ## Prepare Data for Analysis
#
# ### Subtask:
# Ensure the DataFrame is ready for analysis, handling any necessary data type conversions or missing values for the specified columns: 'Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', 'Gender'.

# %% [markdown]
# **Reasoning**:
# The first instruction is to inspect the DataFrame for missing values and data types in the specified columns. I will use `info()` to check data types and `isnull().sum()` to check for missing values for these columns.

# %%
print(df[['Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', 'Gender']].info())
print(df[['Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', 'Gender']].isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1364901814.py in <cell line: 0>()
# ----> 1 print(df[['Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', 'Gender']].info())
#       2 print(df[['Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', 'Gender']].isnull().sum())
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Reasoning**:
# The previous code failed because the 'df' DataFrame was not defined, likely due to the cell where it's loaded not being executed or the kernel state being reset. To fix this, I will re-load the DataFrame 'df' using the filename inferred from the previous successful upload output ('test_lAUu6dG (1).csv') at the beginning of the current cell, and then proceed with checking data types and missing values.

# %%
import pandas as pd
from google.colab import files

# Upload file to ensure it's available in the current session
uploaded = files.upload()

# Load the CSV using the name of the uploaded file
df = pd.read_csv(list(uploaded.keys())[0])

print(df[['Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', 'Gender']].info())
print(df[['Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', 'Gender']].isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4045630255.py in <cell line: 0>()
#       3 # Re-load the CSV to ensure 'df' is defined, assuming the file from the previous upload is accessible.
#       4 # The previous cell's output indicated the file was saved as 'test_lAUu6dG (1).csv'.
# ----> 5 df = pd.read_csv('test_lAUu6dG (1).csv')
#       6
#       7 print(df[['Loan_Status', 'Married', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Education', 'Gender']].info())
#
# ...
